# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import os
import boto3

# %%
os.chdir('../')

# %%
os.listdir('data/procesada')
# Out:
# ['data_with_index.pkl', 'data_with_index.csv']

# %% [markdown]
# # Load data

# %% [markdown]
# ## Labels

# %%
data = pd.read_pickle('data/procesada/data_with_index.pkl')

# %%
data.head()
# Out:
#   model_decision analyst_decision       long        lat state  \
# 0              G                R -43.976775 -19.803989    ac
# 1              G                R -46.650595 -23.457741    ac
# 2              G                R -35.837429  -9.734383    al
# 3              G                R -35.737662  -9.644658    al
# 4              R        NA_string -36.648540  -9.780055    al
#
#                          coordinate_point      census_code
# 0  POINT (-43.97677539999999 -19.8039891)              NaN
# 1  POINT (-46.65059489999999 -23.4577409)              NaN
# 2          POINT (-35.8374292 -9.7343826)  270470805000038
# 3  POINT (-35.7376623 -9.644657700000002)  270430205080034
# 4          POINT (-36.6485399 -9.7800555)  270030005000054

# %% [markdown]
# ## censo - basico

# %%
data_censitarios_basico= pd.read_csv('data/basico/dados_censitarios_consolidados.csv', dtype='str')
#print(data_censitarios_basico.columns)
focus_columns_basico_num = ['BASICO_V001',
       'BASICO_V002', 'BASICO_V003', 'BASICO_V004', 'BASICO_V005',
       'BASICO_V006', 'BASICO_V007', 'BASICO_V008', 'BASICO_V009',
       'BASICO_V010', 'BASICO_V011', 'BASICO_V012']

docus_columns_basico_no_num = ['Cod_setor', 'Situacao_setor', 'Tipo_setor']

# %%
data_censitarios_basico = data_censitarios_basico.loc[:, docus_columns_basico_no_num+focus_columns_basico_num] 

for var_i in focus_columns_basico_num:
    data_censitarios_basico[var_i] = pd.to_numeric(data_censitarios_basico[var_i].str.replace(',', '.'), 
                                                          errors='coerce')

data_censitarios_basico = data_censitarios_basico.rename(columns={'Situacao_setor': 'Situacao_setor_basico'})

# %%
print(data_censitarios_basico.isna().mean()*100)
data_censitarios_basico.head()
# Out:
# Cod_setor                0.000000
# Situacao_setor_basico    0.000000
# Tipo_setor               0.000000
# BASICO_V001              0.269318
# BASICO_V002              0.269318
# BASICO_V003              0.269318
# BASICO_V004              0.269318
# BASICO_V005              0.269318
# BASICO_V006              0.269318
# BASICO_V007              0.337023
# BASICO_V008              0.337023
# BASICO_V009              0.001128
# BASICO_V010              0.001128
# BASICO_V011              0.086889
# BASICO_V012              0.086889
# dtype: float64
#          Cod_setor Situacao_setor_basico Tipo_setor  BASICO_V001  BASICO_V002  \
# 0  350010505000001                     1          0        149.0        304.0
# 1  350010505000002                     1          0        294.0        785.0
# 2  350010505000003                     1          0        214.0        519.0
# 3  350010505000004                     1          0        288.0        788.0
# ...

# %% [markdown]
# ## censo - domicilio

# %%
data_censitarios_domicilio = pd.read_csv('data/domicilio/dados_censitarios_consolidados_domicilio_renda.csv',
                                     dtype='str')

# print(data_censitarios_domicilio.columns)
focus_columns_domicilio_num = ['DOMICILIO_RENDA_V001',
       'DOMICILIO_RENDA_V002', 'DOMICILIO_RENDA_V003', 'DOMICILIO_RENDA_V004',
       'DOMICILIO_RENDA_V005', 'DOMICILIO_RENDA_V006', 'DOMICILIO_RENDA_V007',
       'DOMICILIO_RENDA_V008', 'DOMICILIO_RENDA_V009', 'DOMICILIO_RENDA_V010',
       'DOMICILIO_RENDA_V011', 'DOMICILIO_RENDA_V012', 'DOMICILIO_RENDA_V013',
       'DOMICILIO_RENDA_V014']

docus_columns_domicilio_no_num = ['Cod_setor', 'Situacao_setor']

# %%
data_censitarios_domicilio = data_censitarios_domicilio.loc[:, docus_columns_domicilio_no_num+focus_columns_domicilio_num] 

for var_i in focus_columns_domicilio_num:
    data_censitarios_domicilio[var_i] = pd.to_numeric(data_censitarios_domicilio[var_i].str.replace(',', '.'), 
                                                          errors='coerce')
    
data_censitarios_domicilio = data_censitarios_domicilio.rename(columns={'Situacao_setor': 'Situacao_setor_domicilio'})

# %%
print(data_censitarios_domicilio.isna().mean()*100)
data_censitarios_domicilio.head()
# los missing corresponden a información que aparece con X en la celda original (antes de transformarla a número)
# Out:
# Cod_setor                   0.000000
# Situacao_setor_domicilio    0.000000
# DOMICILIO_RENDA_V001        2.104139
# DOMICILIO_RENDA_V002        2.104139
# DOMICILIO_RENDA_V003        2.104139
# DOMICILIO_RENDA_V004        2.104139
# DOMICILIO_RENDA_V005        2.104139
# DOMICILIO_RENDA_V006        2.104139
# DOMICILIO_RENDA_V007        2.104139
# DOMICILIO_RENDA_V008        2.104139
# DOMICILIO_RENDA_V009        2.104139
# DOMICILIO_RENDA_V010        2.104139
# DOMICILIO_RENDA_V011        2.104139
# DOMICILIO_RENDA_V012        2.104139
# DOMICILIO_RENDA_V013        2.104139
# DOMICILIO_RENDA_V014        2.104139
# dtype: float64
#          Cod_setor Situacao_setor_domicilio  DOMICILIO_RENDA_V001  \
# 0  355030801000001                        1                   2.0
# 1  355030801000002                        1                   0.0
# 2  355030801000003                        1                   0.0
# 3  355030801000004                        1                   0.0
# ...

# %% [markdown]
# ## censo - personas

# %%
data_censitarios_persona = pd.read_csv('data/pessoa/dados_censitarios_consolidados_pessoa_renda.csv',
                                     dtype='str')

#print(data_censitarios_persona.columns.tolist())
focus_columns_persona_num = ['PESSOA_RENDA_V001', 'PESSOA_RENDA_V002', 'PESSOA_RENDA_V003', 'PESSOA_RENDA_V004',
                             'PESSOA_RENDA_V005', 'PESSOA_RENDA_V006', 'PESSOA_RENDA_V007', 'PESSOA_RENDA_V008', 
                             'PESSOA_RENDA_V009', 'PESSOA_RENDA_V010', 'PESSOA_RENDA_V011', 'PESSOA_RENDA_V012',
                             'PESSOA_RENDA_V013', 'PESSOA_RENDA_V014', 'PESSOA_RENDA_V015', 'PESSOA_RENDA_V016',
                             'PESSOA_RENDA_V017', 'PESSOA_RENDA_V018', 'PESSOA_RENDA_V019', 'PESSOA_RENDA_V020', 
                             'PESSOA_RENDA_V021', 'PESSOA_RENDA_V022', 'PESSOA_RENDA_V023', 'PESSOA_RENDA_V024', 
                             'PESSOA_RENDA_V025', 'PESSOA_RENDA_V026', 'PESSOA_RENDA_V027', 'PESSOA_RENDA_V028',
                             'PESSOA_RENDA_V029', 'PESSOA_RENDA_V030', 'PESSOA_RENDA_V031', 'PESSOA_RENDA_V032', 
                             'PESSOA_RENDA_V033', 'PESSOA_RENDA_V034', 'PESSOA_RENDA_V035', 'PESSOA_RENDA_V036',
                             'PESSOA_RENDA_V037', 'PESSOA_RENDA_V038', 'PESSOA_RENDA_V039', 'PESSOA_RENDA_V040', 
                             'PESSOA_RENDA_V041', 'PESSOA_RENDA_V042', 'PESSOA_RENDA_V043', 'PESSOA_RENDA_V044', 
                             'PESSOA_RENDA_V045', 'PESSOA_RENDA_V046', 'PESSOA_RENDA_V047', 'PESSOA_RENDA_V048',
                             'PESSOA_RENDA_V049', 'PESSOA_RENDA_V050', 'PESSOA_RENDA_V051', 'PESSOA_RENDA_V052',
                             'PESSOA_RENDA_V053', 'PESSOA_RENDA_V054', 'PESSOA_RENDA_V055', 'PESSOA_RENDA_V056',
                             'PESSOA_RENDA_V057', 'PESSOA_RENDA_V058', 'PESSOA_RENDA_V059', 'PESSOA_RENDA_V060',
                             'PESSOA_RENDA_V061', 'PESSOA_RENDA_V062', 'PESSOA_RENDA_V063', 'PESSOA_RENDA_V064', 
                             'PESSOA_RENDA_V065', 'PESSOA_RENDA_V066', 'PESSOA_RENDA_V067', 'PESSOA_RENDA_V068', 
                             'PESSOA_RENDA_V069', 'PESSOA_RENDA_V070', 'PESSOA_RENDA_V071', 'PESSOA_RENDA_V072',
                             'PESSOA_RENDA_V073', 'PESSOA_RENDA_V074', 'PESSOA_RENDA_V075', 'PESSOA_RENDA_V076',
                             'PESSOA_RENDA_V077', 'PESSOA_RENDA_V078', 'PESSOA_RENDA_V079', 'PESSOA_RENDA_V080',
                             'PESSOA_RENDA_V081', 'PESSOA_RENDA_V082', 'PESSOA_RENDA_V083', 'PESSOA_RENDA_V084',
                             'PESSOA_RENDA_V085', 'PESSOA_RENDA_V086', 'PESSOA_RENDA_V087', 'PESSOA_RENDA_V088', 
                             'PESSOA_RENDA_V089', 'PESSOA_RENDA_V090', 'PESSOA_RENDA_V091', 'PESSOA_RENDA_V092',
                             'PESSOA_RENDA_V093', 'PESSOA_RENDA_V094', 'PESSOA_RENDA_V095', 'PESSOA_RENDA_V096',
                             'PESSOA_RENDA_V097', 'PESSOA_RENDA_V098', 'PESSOA_RENDA_V099', 'PESSOA_RENDA_V100', 
                             'PESSOA_RENDA_V101', 'PESSOA_RENDA_V102', 'PESSOA_RENDA_V103', 'PESSOA_RENDA_V104', 
                             'PESSOA_RENDA_V105', 'PESSOA_RENDA_V106', 'PESSOA_RENDA_V107', 'PESSOA_RENDA_V108', 
                             'PESSOA_RENDA_V109', 'PESSOA_RENDA_V110', 'PESSOA_RENDA_V111', 'PESSOA_RENDA_V112',
                             'PESSOA_RENDA_V113', 'PESSOA_RENDA_V114', 'PESSOA_RENDA_V115', 'PESSOA_RENDA_V116', 
                             'PESSOA_RENDA_V117', 'PESSOA_RENDA_V118', 'PESSOA_RENDA_V119', 'PESSOA_RENDA_V120',
                             'PESSOA_RENDA_V121', 'PESSOA_RENDA_V122', 'PESSOA_RENDA_V123', 'PESSOA_RENDA_V124',
                             'PESSOA_RENDA_V125', 'PESSOA_RENDA_V126', 'PESSOA_RENDA_V127', 'PESSOA_RENDA_V128', 
                             'PESSOA_RENDA_V129', 'PESSOA_RENDA_V130', 'PESSOA_RENDA_V131', 'PESSOA_RENDA_V132']


focus_columns_persona_no_num = ['Cod_setor', 'Situacao_setor']

# %%
data_censitarios_persona = data_censitarios_persona.loc[:, focus_columns_persona_no_num+focus_columns_persona_num] 

for var_i in focus_columns_persona_num:
    data_censitarios_persona[var_i+'_num'] = pd.to_numeric(data_censitarios_persona[var_i].str.replace(',', '.'), 
                                                          errors='coerce')
    
data_censitarios_persona = data_censitarios_persona.rename(columns={'Situacao_setor': 'Situacao_setor_persona'})

# %%
print(data_censitarios_persona.isna().mean()*100)
data_censitarios_persona.head()
# los missing corresponden a información que aparece con X en la celda original (antes de transformarla a número)
# Out:
# Cod_setor                 0.000000
# Situacao_setor_persona    0.000000
# PESSOA_RENDA_V001         0.000000
# PESSOA_RENDA_V002         0.000000
# PESSOA_RENDA_V003         0.000000
#                             ...
# PESSOA_RENDA_V128_num     2.104139
# PESSOA_RENDA_V129_num     2.104139
# PESSOA_RENDA_V130_num     2.104139
# PESSOA_RENDA_V131_num     2.104139
# PESSOA_RENDA_V132_num     2.104139
# Length: 266, dtype: float64
#          Cod_setor Situacao_setor_persona PESSOA_RENDA_V001 PESSOA_RENDA_V002  \
# 0  355030801000001                      1                 2                93
# 1  355030801000002                      1                 6               138
# 2  355030801000003                      1                 1                32
# 3  355030801000004                      1                 2                24
# 4  355030801000005                      1                 3                99
#
#   PESSOA_RENDA_V003 PESSOA_RENDA_V004 PESSOA_RENDA_V005 PESSOA_RENDA_V006  \
# ...

# %% [markdown]
# # Join

# %%
data = (data
        .dropna(subset=['census_code'])
        .merge(data_censitarios_basico,left_on='census_code', right_on='Cod_setor', how='left')
        .merge(data_censitarios_domicilio,left_on='census_code', right_on='Cod_setor', how='left')
        .merge(data_censitarios_persona,left_on='census_code', right_on='Cod_setor', how='left')
       )

# %% [markdown]
# # Exportar data

# %%
data.to_csv('data/procesada/data_plus_census.csv', index=False)
data.to_pickle('data/procesada/data_plus_census.pkl')

# %% [markdown]
# ## Cargar data a S3

# %%
AWS_ACCESS_KEY = ' AKIARQBCIP76L6XVXIVQ'
AWS_SECRET_ACCESS_KEY = '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'
S3_BUCKET_NAME = 'ds4ateam5'

s3_client = boto3.resource(
    's3',
    aws_access_key_id=AWS_ACCESS_KEY,
    aws_secret_access_key=AWS_SECRET_ACCESS_KEY
)

s3_bucket = s3_client.Bucket(S3_BUCKET_NAME)
local_folder = '.'

# %%
for file_i in ['data/procesada/data_plus_census.csv',
               'data/procesada/data_plus_census.pkl']:
    
    s3_bucket.upload_file(file_i, file_i)
